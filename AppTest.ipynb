# %%
import plotly.express as px
import pandas as pd
import streamlit as st

#st.title("Best Games on BGG")

# %%
url ='https://github.com/cchristensn/datacuration/blob/main/GameRanks.csv/?raw=True'
df = pd.read_csv(url, index_col=0)

# %%
# Out:
# 'Dreamblade'

# %%
print(x)
# Out:
# 548    Monikers

# %%
df
# Out:
#                                                   Name  Year      ID   Rating  \
# 0                                    Brass: Birmingham  2018  224517  8.41705
# 1                            Pandemic Legacy: Season 1  2015  161936  8.38317
# 2                                           Gloomhaven  2017  174430  8.36184
# 3                                             Ark Nova  2021  342942  8.33346
# 4                    Twilight Imperium: Fourth Edition  2017  233078  8.24315
# ..                                                 ...   ...     ...      ...
# 746  The Devil's Cauldron: The Battles for Arnhem a...  2008   15369  5.92187
# 747                        Successors (Fourth Edition)  2022  325348  6.09386
# 748                                              Polis  2020  303551  6.20844
# 749          Roads to Gettysburg II: Lee Strikes North  2018  215565  5.85047
# 750                                    D-Day at Tarawa  2014   67600  5.97233
#
#      Complexity  Overall Rank  Plays Last Month   Owns  Wants  Wishlists  \
# 0        3.8836             1              1703  61495   1735      17615
# 1        2.8317             2               823  82267    813      13567
# 2        3.9072             3              1934  96001   1193      20184
# 3        3.7493             4             12463  60548   1044      12923
# 4        4.3171             5               485  28412   1035      11288
# ..          ...           ...               ...    ...    ...        ...
# 746      3.8372          3350                 3    910    140        447
# 747      4.0652          2432                21   2278     91        698
# 748      3.7869          1978                17   1894    101        764
# 749      3.6667          3874                 8    919     68        188
# 750      3.7255          3016                 2   1789    111        459
#
#      Abstract Rank  Customizable Rank  Thematic Rank  Family Rank  \
# 0              NaN                NaN            NaN          NaN
# 1              NaN                NaN            1.0          NaN
# 2              NaN                NaN            2.0          NaN
# 3              NaN                NaN            NaN          NaN
# 4              NaN                NaN            3.0          NaN
# ..             ...                ...            ...          ...
# 746            NaN                NaN            NaN          NaN
# 747            NaN                NaN            NaN          NaN
# 748            NaN                NaN            NaN          NaN
# 749            NaN                NaN            NaN          NaN
# 750            NaN                NaN            NaN          NaN
#
#      Children Rank  Party Rank  Strategy Rank  War Rank
# 0              NaN         NaN            1.0       NaN
# 1              NaN         NaN            2.0       NaN
# 2              NaN         NaN            4.0       NaN
# 3              NaN         NaN            3.0       NaN
# 4              NaN         NaN            5.0       NaN
# ..             ...         ...            ...       ...
# 746            NaN         NaN            NaN      96.0
# 747            NaN         NaN            NaN      97.0
# 748            NaN         NaN            NaN      98.0
# 749            NaN         NaN            NaN      99.0
# 750            NaN         NaN            NaN     100.0
#
# [751 rows x 18 columns]
